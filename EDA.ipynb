# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Get the data

# %%
import pandas as pd

data = pd.read_csv("csv/signes.csv")

# %%
data.head()
# Out:
#                        video_name  EAR_left_0  EAR_right_0  EAR_mean_0  \
# 0   kss#1-3#F#rldd#17-0.mp4_1.mp4    0.368546     0.371066    0.369806
# 1   kss#1-3#F#rldd#21-0.mp4_1.mp4    0.315517     0.281914    0.298715
# 2   kss#1-3#F#rldd#57-0.mp4_5.mp4    0.312824     0.290006    0.301415
# 3   kss#1-3#F#rldd#59-0.mp4_4.mp4    0.331562     0.346838    0.339200
# 4  kss#8-9#F#rldd#12-10.mp4_3.mp4    0.318018     0.338801    0.328409
#
#       MAR_0  EBR_0  PERCLOS_0   HOP_gd_0  HOP_hb_0  EAR_left_1  ...  \
# 0  0.003794      0        0.0  89.996526  4.465502    0.378372  ...
# 1  0.006160      0        0.0  90.012625  2.051549    0.314886  ...
# 2  0.003691      0        0.0  90.021010  5.515728    0.321846  ...
# 3  0.003254      0        0.0  89.986877  1.336402    0.341735  ...
# 4  0.009697      0        0.0  89.974311  4.051703    0.320297  ...
#
#    HOP_hb_873  EAR_left_874  EAR_right_874  EAR_mean_874   MAR_874  EBR_874  \
# 0    3.538908      0.366793       0.366085      0.366439  0.003091        0
# 1    5.143141      0.345992       0.292497      0.319244  0.007726        0
# 2    4.564574      0.286394       0.249781      0.268087  0.006888        1
# 3    0.507546      0.348462       0.353522      0.350992  0.003047        0
# 4    2.222282      0.122808       0.119565      0.121187  0.009761        1
#
#    PERCLOS_874  HOP_gd_874  HOP_hb_874  class
# 0     8.000000   89.994856    3.620867      0
# 1     2.400000   90.015657    5.207324      0
# 2     4.800000   90.026613    4.552479      0
# 3    13.714286   89.994275    0.511410      0
# 4    21.714286   89.975156    2.369169      2
#
# [5 rows x 7002 columns]

# %%
data.to_csv("csv/signes.csv",index=False)

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 7002 columns):
#  #     Column         Dtype
# ---    ------         -----
#  0     video_name     object
#  1     EAR_left_0     float64
#  2     EAR_right_0    float64
#  3     EAR_mean_0     float64
#  4     MAR_0          float64
#  5     EBR_0          int64
#  6     PERCLOS_0      float64
#  7     HOP_gd_0       float64
#  8     HOP_hb_0       float64
#  9     EAR_left_1     float64
#  10    EAR_right_1    float64
#  11    EAR_mean_1     float64
#  12    MAR_1          float64
#  13    EBR_1          int64
#  14    PERCLOS_1      float64
#  15    HOP_gd_1       float64
#  16    HOP_hb_1       float64
#  17    EAR_left_2     float64
#  18    EAR_right_2    float64
#  19    EAR_mean_2     float64
#  20    MAR_2          float64
#  21    EBR_2          int64
#  22    PERCLOS_2      float64
#  23    HOP_gd_2       float64
#  24    HOP_hb_2       float64
#  25    EAR_left_3     float64
#  26    EAR_right_3    float64
#  27    EAR_mean_3     float64
#  28    MAR_3          float64
#  29    EBR_3          int64
#  30    PERCLOS_3      float64
#  31    HOP_gd_3       float64
#  32    HOP_hb_3       float64
#  33    EAR_left_4     float64
#  34    EAR_right_4    float64
#  35    EAR_mean_4     float64
#  36    MAR_4          float64
#  37    EBR_4          int64
#  38    PERCLOS_4      float64
#  39    HOP_gd_4       float64
#  40    HOP_hb_4       float64
#  41    EAR_left_5     float64
#  42    EAR_right_5    float64
#  43    EAR_mean_5     float64
#  44    MAR_5          float64
#  45    EBR_5          int64
#  46    PERCLOS_5      float64
#  47    HOP_gd_5       float64
#  48    HOP_hb_5       float64
#  49    EAR_left_6     float64
#  50    EAR_right_6    float64
#  51    EAR_mean_6     float64
#  52    MAR_6          float64
#  53    EBR_6          int64
#  54    PERCLOS_6      float64
#  55    HOP_gd_6       float64
#  56    HOP_hb_6       float64
#  57    EAR_left_7     float64
#  58    EAR_right_7    float64
#  59    EAR_mean_7     float64
#  60    MAR_7          float64
#  61    EBR_7          int64
#  62    PERCLOS_7      float64
#  63    HOP_gd_7       float64
#  64    HOP_hb_7       float64
#  65    EAR_left_8     float64
#  66    EAR_right_8    float64
#  67    EAR_mean_8     float64
#  68    MAR_8          float64
#  69    EBR_8          int64
#  70    PERCLOS_8      float64
#  71    HOP_gd_8       float64
#  72    HOP_hb_8       float64
#  73    EAR_left_9     float64
#  74    EAR_right_9    float64
#  75    EAR_mean_9     float64
#  76    MAR_9          float64
#  77    EBR_9          int64
#  78    PERCLOS_9      float64
#  79    HOP_gd_9       float64
#  80    HOP_hb_9       float64
#  81    EAR_left_10    float64
#  82    EAR_right_10   float64
#  83    EAR_mean_10    float64
#  84    MAR_10         float64
#  85    EBR_10         int64
#  86    PERCLOS_10     float64
#  87    HOP_gd_10      float64
#  88    HOP_hb_10      float64
#  89    EAR_left_11    float64
#  90    EAR_right_11   float64
#  91    EAR_mean_11    float64
#  92    MAR_11         float64
#  93    EBR_11         int64
#  94    PERCLOS_11     float64
#  95    HOP_gd_11      float64
#  96    HOP_hb_11      float64
#  97    EAR_left_12    float64
#  98    EAR_right_12   float64
#  99    EAR_mean_12    float64
#  100   MAR_12         float64
#  101   EBR_12         int64
#  102   PERCLOS_12     float64
#  103   HOP_gd_12      float64
#  104   HOP_hb_12      float64
#  105   EAR_left_13    float64
#  106   EAR_right_13   float64
#  107   EAR_mean_13    float64
#  108   MAR_13         float64
#  109   EBR_13         int64
#  110   PERCLOS_13     float64
#  111   HOP_gd_13      float64
#  112   HOP_hb_13      float64
#  113   EAR_left_14    float64
#  114   EAR_right_14   float64
#  115   EAR_mean_14    float64
#  116   MAR_14         float64
#  117   EBR_14         int64
#  118   PERCLOS_14     float64
#  119   HOP_gd_14      float64
#  120   HOP_hb_14      float64
#  121   EAR_left_15    float64
#  122   EAR_right_15   float64
#  123   EAR_mean_15    float64
#  124   MAR_15         float64
#  125   EBR_15         int64
#  126   PERCLOS_15     float64
#  127   HOP_gd_15      float64
#  128   HOP_hb_15      float64
#  129   EAR_left_16    float64
#  130   EAR_right_16   float64
#  131   EAR_mean_16    float64
#  132   MAR_16         float64
#  133   EBR_16         int64
#  134   PERCLOS_16     float64
#  135   HOP_gd_16      float64
#  136   HOP_hb_16      float64
#  137   EAR_left_17    float64
#  138   EAR_right_17   float64
#  139   EAR_mean_17    float64
#  140   MAR_17         float64
#  141   EBR_17         int64
#  142   PERCLOS_17     float64
#  143   HOP_gd_17      float64
#  144   HOP_hb_17      float64
#  145   EAR_left_18    float64
#  146   EAR_right_18   float64
#  147   EAR_mean_18    float64
#  148   MAR_18         float64
#  149   EBR_18         int64
#  150   PERCLOS_18     float64
#  151   HOP_gd_18      float64
#  152   HOP_hb_18      float64
#  153   EAR_left_19    float64
#  154   EAR_right_19   float64
#  155   EAR_mean_19    float64
#  156   MAR_19         float64
#  157   EBR_19         int64
#  158   PERCLOS_19     float64
#  159   HOP_gd_19      float64
#  160   HOP_hb_19      float64
#  161   EAR_left_20    float64
#  162   EAR_right_20   float64
#  163   EAR_mean_20    float64
#  164   MAR_20         float64
#  165   EBR_20         int64
#  166   PERCLOS_20     float64
#  167   HOP_gd_20      float64
#  168   HOP_hb_20      float64
#  169   EAR_left_21    float64
#  170   EAR_right_21   float64
#  171   EAR_mean_21    float64
#  172   MAR_21         float64
#  173   EBR_21         int64
#  174   PERCLOS_21     float64
#  175   HOP_gd_21      float64
#  176   HOP_hb_21      float64
#  177   EAR_left_22    float64
#  178   EAR_right_22   float64
#  179   EAR_mean_22    float64
#  180   MAR_22         float64
#  181   EBR_22         int64
#  182   PERCLOS_22     float64
#  183   HOP_gd_22      float64
#  184   HOP_hb_22      float64
#  185   EAR_left_23    float64
#  186   EAR_right_23   float64
#  187   EAR_mean_23    float64
#  188   MAR_23         float64
#  189   EBR_23         int64
#  190   PERCLOS_23     float64
#  191   HOP_gd_23      float64
#  192   HOP_hb_23      float64
#  193   EAR_left_24    float64
#  194   EAR_right_24   float64
#  195   EAR_mean_24    float64
#  196   MAR_24         float64
#  197   EBR_24         int64
#  198   PERCLOS_24     float64
#  199   HOP_gd_24      float64
#  200   HOP_hb_24      float64
#  201   EAR_left_25    float64
#  202   EAR_right_25   float64
#  203   EAR_mean_25    float64
#  204   MAR_25         float64
#  205   EBR_25         int64
#  206   PERCLOS_25     float64
#  207   HOP_gd_25      float64
#  208   HOP_hb_25      float64
#  209   EAR_left_26    float64
#  210   EAR_right_26   float64
#  211   EAR_mean_26    float64
#  212   MAR_26         float64
#  213   EBR_26         int64
#  214   PERCLOS_26     float64
#  215   HOP_gd_26      float64
#  216   HOP_hb_26      float64
#  217   EAR_left_27    float64
#  218   EAR_right_27   float64
#  219   EAR_mean_27    float64
#  220   MAR_27         float64
#  221   EBR_27         int64
#  222   PERCLOS_27     float64
#  223   HOP_gd_27      float64
#  224   HOP_hb_27      float64
#  225   EAR_left_28    float64
#  226   EAR_right_28   float64
#  227   EAR_mean_28    float64
#  228   MAR_28         float64
#  229   EBR_28         int64
#  230   PERCLOS_28     float64
#  231   HOP_gd_28      float64
#  232   HOP_hb_28      float64
#  233   EAR_left_29    float64
#  234   EAR_right_29   float64
#  235   EAR_mean_29    float64
#  236   MAR_29         float64
#  237   EBR_29         int64
#  238   PERCLOS_29     float64
#  239   HOP_gd_29      float64
#  240   HOP_hb_29      float64
#  241   EAR_left_30    float64
#  242   EAR_right_30   float64
#  243   EAR_mean_30    float64
#  244   MAR_30         float64
#  245   EBR_30         int64
#  246   PERCLOS_30     float64
#  247   HOP_gd_30      float64
#  248   HOP_hb_30      float64
#  249   EAR_left_31    float64
#  250   EAR_right_31   float64
#  251   EAR_mean_31    float64
#  252   MAR_31         float64
#  253   EBR_31         int64
#  254   PERCLOS_31     float64
#  255   HOP_gd_31      float64
#  256   HOP_hb_31      float64
#  257   EAR_left_32    float64
#  258   EAR_right_32   float64
#  259   EAR_mean_32    float64
#  260   MAR_32         float64
#  261   EBR_32         int64
#  262   PERCLOS_32     float64
#  263   HOP_gd_32      float64
#  264   HOP_hb_32      float64
#  265   EAR_left_33    float64
#  266   EAR_right_33   float64
#  267   EAR_mean_33    float64
#  268   MAR_33         float64
#  269   EBR_33         int64
#  270   PERCLOS_33     float64
#  271   HOP_gd_33      float64
#  272   HOP_hb_33      float64
#  273   EAR_left_34    float64
#  274   EAR_right_34   float64
#  275   EAR_mean_34    float64
#  276   MAR_34         float64
#  277   EBR_34         int64
#  278   PERCLOS_34     float64
#  279   HOP_gd_34      float64
#  280   HOP_hb_34      float64
#  281   EAR_left_35    float64
#  282   EAR_right_35   float64
#  283   EAR_mean_35    float64
#  284   MAR_35         float64
#  285   EBR_35         int64
#  286   PERCLOS_35     float64
#  287   HOP_gd_35      float64
#  288   HOP_hb_35      float64
#  289   EAR_left_36    float64
#  290   EAR_right_36   float64
#  291   EAR_mean_36    float64
#  292   MAR_36         float64
#  293   EBR_36         int64
#  294   PERCLOS_36     float64
#  295   HOP_gd_36      float64
#  296   HOP_hb_36      float64
#  297   EAR_left_37    float64
#  298   EAR_right_37   float64
#  299   EAR_mean_37    float64
#  300   MAR_37         float64
#  301   EBR_37         int64
#  302   PERCLOS_37     float64
#  303   HOP_gd_37      float64
#  304   HOP_hb_37      float64
#  305   EAR_left_38    float64
#  306   EAR_right_38   float64
#  307   EAR_mean_38    float64
#  308   MAR_38         float64
#  309   EBR_38         int64
#  310   PERCLOS_38     float64
#  311   HOP_gd_38      float64
#  312   HOP_hb_38      float64
#  313   EAR_left_39    float64
#  314   EAR_right_39   float64
#  315   EAR_mean_39    float64
#  316   MAR_39         float64
#  317   EBR_39         int64
#  318   PERCLOS_39     float64
#  319   HOP_gd_39      float64
#  320   HOP_hb_39      float64
#  321   EAR_left_40    float64
#  322   EAR_right_40   float64
#  323   EAR_mean_40    float64
#  324   MAR_40         float64
#  325   EBR_40         int64
#  326   PERCLOS_40     float64
#  327   HOP_gd_40      float64
#  328   HOP_hb_40      float64
#  329   EAR_left_41    float64
#  330   EAR_right_41   float64
#  331   EAR_mean_41    float64
#  332   MAR_41         float64
#  333   EBR_41         int64
#  334   PERCLOS_41     float64
#  335   HOP_gd_41      float64
#  336   HOP_hb_41      float64
#  337   EAR_left_42    float64
#  338   EAR_right_42   float64
#  339   EAR_mean_42    float64
#  340   MAR_42         float64
#  341   EBR_42         int64
#  342   PERCLOS_42     float64
#  343   HOP_gd_42      float64
#  344   HOP_hb_42      float64
#  345   EAR_left_43    float64
#  346   EAR_right_43   float64
#  347   EAR_mean_43    float64
#  348   MAR_43         float64
#  349   EBR_43         int64
#  350   PERCLOS_43     float64
#  351   HOP_gd_43      float64
#  352   HOP_hb_43      float64
#  353   EAR_left_44    float64
#  354   EAR_right_44   float64
#  355   EAR_mean_44    float64
#  356   MAR_44         float64
#  357   EBR_44         int64
#  358   PERCLOS_44     float64
#  359   HOP_gd_44      float64
#  360   HOP_hb_44      float64
#  361   EAR_left_45    float64
#  362   EAR_right_45   float64
#  363   EAR_mean_45    float64
#  364   MAR_45         float64
#  365   EBR_45         int64
#  366   PERCLOS_45     float64
#  367   HOP_gd_45      float64
#  368   HOP_hb_45      float64
#  369   EAR_left_46    float64
#  370   EAR_right_46   float64
#  371   EAR_mean_46    float64
#  372   MAR_46         float64
#  373   EBR_46         int64
#  374   PERCLOS_46     float64
#  375   HOP_gd_46      float64
#  376   HOP_hb_46      float64
#  377   EAR_left_47    float64
#  378   EAR_right_47   float64
#  379   EAR_mean_47    float64
#  380   MAR_47         float64
#  381   EBR_47         int64
#  382   PERCLOS_47     float64
#  383   HOP_gd_47      float64
#  384   HOP_hb_47      float64
#  385   EAR_left_48    float64
#  386   EAR_right_48   float64
#  387   EAR_mean_48    float64
#  388   MAR_48         float64
#  389   EBR_48         int64
#  390   PERCLOS_48     float64
#  391   HOP_gd_48      float64
#  392   HOP_hb_48      float64
#  393   EAR_left_49    float64
#  394   EAR_right_49   float64
#  395   EAR_mean_49    float64
#  396   MAR_49         float64
#  397   EBR_49         int64
#  398   PERCLOS_49     float64
#  399   HOP_gd_49      float64
#  400   HOP_hb_49      float64
#  401   EAR_left_50    float64
#  402   EAR_right_50   float64
#  403   EAR_mean_50    float64
#  404   MAR_50         float64
#  405   EBR_50         int64
#  406   PERCLOS_50     float64
#  407   HOP_gd_50      float64
#  408   HOP_hb_50      float64
#  409   EAR_left_51    float64
#  410   EAR_right_51   float64
#  411   EAR_mean_51    float64
#  412   MAR_51         float64
#  413   EBR_51         int64
#  414   PERCLOS_51     float64
#  415   HOP_gd_51      float64
#  416   HOP_hb_51      float64
#  417   EAR_left_52    float64
#  418   EAR_right_52   float64
#  419   EAR_mean_52    float64
#  420   MAR_52         float64
#  421   EBR_52         int64
#  422   PERCLOS_52     float64
#  423   HOP_gd_52      float64
#  424   HOP_hb_52      float64
#  425   EAR_left_53    float64
#  426   EAR_right_53   float64
#  427   EAR_mean_53    float64
#  428   MAR_53         float64
#  429   EBR_53         int64
#  430   PERCLOS_53     float64
#  431   HOP_gd_53      float64
#  432   HOP_hb_53      float64
#  433   EAR_left_54    float64
#  434   EAR_right_54   float64
#  435   EAR_mean_54    float64
#  436   MAR_54         float64
#  437   EBR_54         int64
#  438   PERCLOS_54     float64
#  439   HOP_gd_54      float64
#  440   HOP_hb_54      float64
#  441   EAR_left_55    float64
#  442   EAR_right_55   float64
#  443   EAR_mean_55    float64
#  444   MAR_55         float64
#  445   EBR_55         int64
#  446   PERCLOS_55     float64
#  447   HOP_gd_55      float64
#  448   HOP_hb_55      float64
#  449   EAR_left_56    float64
#  450   EAR_right_56   float64
#  451   EAR_mean_56    float64
#  452   MAR_56         float64
#  453   EBR_56         int64
#  454   PERCLOS_56     float64
#  455   HOP_gd_56      float64
#  456   HOP_hb_56      float64
#  457   EAR_left_57    float64
#  458   EAR_right_57   float64
#  459   EAR_mean_57    float64
#  460   MAR_57         float64
#  461   EBR_57         int64
#  462   PERCLOS_57     float64
#  463   HOP_gd_57      float64
#  464   HOP_hb_57      float64
#  465   EAR_left_58    float64
#  466   EAR_right_58   float64
#  467   EAR_mean_58    float64
#  468   MAR_58         float64
#  469   EBR_58         int64
#  470   PERCLOS_58     float64
#  471   HOP_gd_58      float64
#  472   HOP_hb_58      float64
#  473   EAR_left_59    float64
#  474   EAR_right_59   float64
#  475   EAR_mean_59    float64
#  476   MAR_59         float64
#  477   EBR_59         int64
#  478   PERCLOS_59     float64
#  479   HOP_gd_59      float64
#  480   HOP_hb_59      float64
#  481   EAR_left_60    float64
#  482   EAR_right_60   float64
#  483   EAR_mean_60    float64
#  484   MAR_60         float64
#  485   EBR_60         int64
#  486   PERCLOS_60     float64
#  487   HOP_gd_60      float64
#  488   HOP_hb_60      float64
#  489   EAR_left_61    float64
#  490   EAR_right_61   float64
#  491   EAR_mean_61    float64
#  492   MAR_61         float64
#  493   EBR_61         int64
#  494   PERCLOS_61     float64
#  495   HOP_gd_61      float64
#  496   HOP_hb_61      float64
#  497   EAR_left_62    float64
#  498   EAR_right_62   float64
#  499   EAR_mean_62    float64
#  500   MAR_62         float64
#  501   EBR_62         int64
#  502   PERCLOS_62     float64
#  503   HOP_gd_62      float64
#  504   HOP_hb_62      float64
#  505   EAR_left_63    float64
#  506   EAR_right_63   float64
#  507   EAR_mean_63    float64
#  508   MAR_63         float64
#  509   EBR_63         int64
#  510   PERCLOS_63     float64
#  511   HOP_gd_63      float64
#  512   HOP_hb_63      float64
#  513   EAR_left_64    float64
#  514   EAR_right_64   float64
#  515   EAR_mean_64    float64
#  516   MAR_64         float64
#  517   EBR_64         int64
#  518   PERCLOS_64     float64
#  519   HOP_gd_64      float64
#  520   HOP_hb_64      float64
#  521   EAR_left_65    float64
#  522   EAR_right_65   float64
#  523   EAR_mean_65    float64
#  524   MAR_65         float64
#  525   EBR_65         int64
#  526   PERCLOS_65     float64
#  527   HOP_gd_65      float64
#  528   HOP_hb_65      float64
#  529   EAR_left_66    float64
#  530   EAR_right_66   float64
#  531   EAR_mean_66    float64
#  532   MAR_66         float64
#  533   EBR_66         int64
#  534   PERCLOS_66     float64
#  535   HOP_gd_66      float64
#  536   HOP_hb_66      float64
#  537   EAR_left_67    float64
#  538   EAR_right_67   float64
#  539   EAR_mean_67    float64
#  540   MAR_67         float64
#  541   EBR_67         int64
#  542   PERCLOS_67     float64
#  543   HOP_gd_67      float64
#  544   HOP_hb_67      float64
#  545   EAR_left_68    float64
#  546   EAR_right_68   float64
#  547   EAR_mean_68    float64
#  548   MAR_68         float64
#  549   EBR_68         int64
#  550   PERCLOS_68     float64
#  551   HOP_gd_68      float64
#  552   HOP_hb_68      float64
#  553   EAR_left_69    float64
#  554   EAR_right_69   float64
#  555   EAR_mean_69    float64
#  556   MAR_69         float64
#  557   EBR_69         int64
#  558   PERCLOS_69     float64
#  559   HOP_gd_69      float64
#  560   HOP_hb_69      float64
#  561   EAR_left_70    float64
#  562   EAR_right_70   float64
#  563   EAR_mean_70    float64
#  564   MAR_70         float64
#  565   EBR_70         int64
#  566   PERCLOS_70     float64
#  567   HOP_gd_70      float64
#  568   HOP_hb_70      float64
#  569   EAR_left_71    float64
#  570   EAR_right_71   float64
#  571   EAR_mean_71    float64
#  572   MAR_71         float64
#  573   EBR_71         int64
#  574   PERCLOS_71     float64
#  575   HOP_gd_71      float64
#  576   HOP_hb_71      float64
#  577   EAR_left_72    float64
#  578   EAR_right_72   float64
#  579   EAR_mean_72    float64
#  580   MAR_72         float64
#  581   EBR_72         int64
#  582   PERCLOS_72     float64
#  583   HOP_gd_72      float64
#  584   HOP_hb_72      float64
#  585   EAR_left_73    float64
#  586   EAR_right_73   float64
#  587   EAR_mean_73    float64
#  588   MAR_73         float64
#  589   EBR_73         int64
#  590   PERCLOS_73     float64
#  591   HOP_gd_73      float64
#  592   HOP_hb_73      float64
#  593   EAR_left_74    float64
#  594   EAR_right_74   float64
#  595   EAR_mean_74    float64
#  596   MAR_74         float64
#  597   EBR_74         int64
#  598   PERCLOS_74     float64
#  599   HOP_gd_74      float64
#  600   HOP_hb_74      float64
#  601   EAR_left_75    float64
#  602   EAR_right_75   float64
#  603   EAR_mean_75    float64
#  604   MAR_75         float64
#  605   EBR_75         int64
#  606   PERCLOS_75     float64
#  607   HOP_gd_75      float64
#  608   HOP_hb_75      float64
#  609   EAR_left_76    float64
#  610   EAR_right_76   float64
#  611   EAR_mean_76    float64
#  612   MAR_76         float64
#  613   EBR_76         int64
#  614   PERCLOS_76     float64
#  615   HOP_gd_76      float64
#  616   HOP_hb_76      float64
#  617   EAR_left_77    float64
#  618   EAR_right_77   float64
#  619   EAR_mean_77    float64
#  620   MAR_77         float64
#  621   EBR_77         int64
#  622   PERCLOS_77     float64
#  623   HOP_gd_77      float64
#  624   HOP_hb_77      float64
#  625   EAR_left_78    float64
#  626   EAR_right_78   float64
#  627   EAR_mean_78    float64
#  628   MAR_78         float64
#  629   EBR_78         int64
#  630   PERCLOS_78     float64
#  631   HOP_gd_78      float64
#  632   HOP_hb_78      float64
#  633   EAR_left_79    float64
#  634   EAR_right_79   float64
#  635   EAR_mean_79    float64
#  636   MAR_79         float64
#  637   EBR_79         int64
#  638   PERCLOS_79     float64
#  639   HOP_gd_79      float64
#  640   HOP_hb_79      float64
#  641   EAR_left_80    float64
#  642   EAR_right_80   float64
#  643   EAR_mean_80    float64
#  644   MAR_80         float64
#  645   EBR_80         int64
#  646   PERCLOS_80     float64
#  647   HOP_gd_80      float64
#  648   HOP_hb_80      float64
#  649   EAR_left_81    float64
#  650   EAR_right_81   float64
#  651   EAR_mean_81    float64
#  652   MAR_81         float64
#  653   EBR_81         int64
#  654   PERCLOS_81     float64
#  655   HOP_gd_81      float64
#  656   HOP_hb_81      float64
#  657   EAR_left_82    float64
#  658   EAR_right_82   float64
#  659   EAR_mean_82    float64
#  660   MAR_82         float64
#  661   EBR_82         int64
#  662   PERCLOS_82     float64
#  663   HOP_gd_82      float64
#  664   HOP_hb_82      float64
#  665   EAR_left_83    float64
#  666   EAR_right_83   float64
#  667   EAR_mean_83    float64
#  668   MAR_83         float64
#  669   EBR_83         int64
#  670   PERCLOS_83     float64
#  671   HOP_gd_83      float64
#  672   HOP_hb_83      float64
#  673   EAR_left_84    float64
#  674   EAR_right_84   float64
#  675   EAR_mean_84    float64
#  676   MAR_84         float64
#  677   EBR_84         int64
#  678   PERCLOS_84     float64
#  679   HOP_gd_84      float64
#  680   HOP_hb_84      float64
#  681   EAR_left_85    float64
#  682   EAR_right_85   float64
#  683   EAR_mean_85    float64
#  684   MAR_85         float64
#  685   EBR_85         int64
#  686   PERCLOS_85     float64
#  687   HOP_gd_85      float64
#  688   HOP_hb_85      float64
#  689   EAR_left_86    float64
#  690   EAR_right_86   float64
#  691   EAR_mean_86    float64
#  692   MAR_86         float64
#  693   EBR_86         int64
#  694   PERCLOS_86     float64
#  695   HOP_gd_86      float64
#  696   HOP_hb_86      float64
#  697   EAR_left_87    float64
#  698   EAR_right_87   float64
#  699   EAR_mean_87    float64
#  700   MAR_87         float64
#  701   EBR_87         int64
#  702   PERCLOS_87     float64
#  703   HOP_gd_87      float64
#  704   HOP_hb_87      float64
#  705   EAR_left_88    float64
#  706   EAR_right_88   float64
#  707   EAR_mean_88    float64
#  708   MAR_88         float64
#  709   EBR_88         int64
#  710   PERCLOS_88     float64
#  711   HOP_gd_88      float64
#  712   HOP_hb_88      float64
#  713   EAR_left_89    float64
#  714   EAR_right_89   float64
#  715   EAR_mean_89    float64
#  716   MAR_89         float64
#  717   EBR_89         int64
#  718   PERCLOS_89     float64
#  719   HOP_gd_89      float64
#  720   HOP_hb_89      float64
#  721   EAR_left_90    float64
#  722   EAR_right_90   float64
#  723   EAR_mean_90    float64
#  724   MAR_90         float64
#  725   EBR_90         int64
#  726   PERCLOS_90     float64
#  727   HOP_gd_90      float64
#  728   HOP_hb_90      float64
#  729   EAR_left_91    float64
#  730   EAR_right_91   float64
#  731   EAR_mean_91    float64
#  732   MAR_91         float64
#  733   EBR_91         int64
#  734   PERCLOS_91     float64
#  735   HOP_gd_91      float64
#  736   HOP_hb_91      float64
#  737   EAR_left_92    float64
#  738   EAR_right_92   float64
#  739   EAR_mean_92    float64
#  740   MAR_92         float64
#  741   EBR_92         int64
#  742   PERCLOS_92     float64
#  743   HOP_gd_92      float64
#  744   HOP_hb_92      float64
#  745   EAR_left_93    float64
#  746   EAR_right_93   float64
#  747   EAR_mean_93    float64
#  748   MAR_93         float64
#  749   EBR_93         int64
#  750   PERCLOS_93     float64
#  751   HOP_gd_93      float64
#  752   HOP_hb_93      float64
#  753   EAR_left_94    float64
#  754   EAR_right_94   float64
#  755   EAR_mean_94    float64
#  756   MAR_94         float64
#  757   EBR_94         int64
#  758   PERCLOS_94     float64
#  759   HOP_gd_94      float64
#  760   HOP_hb_94      float64
#  761   EAR_left_95    float64
#  762   EAR_right_95   float64
#  763   EAR_mean_95    float64
#  764   MAR_95         float64
#  765   EBR_95         int64
#  766   PERCLOS_95     float64
#  767   HOP_gd_95      float64
#  768   HOP_hb_95      float64
#  769   EAR_left_96    float64
#  770   EAR_right_96   float64
#  771   EAR_mean_96    float64
#  772   MAR_96         float64
#  773   EBR_96         int64
#  774   PERCLOS_96     float64
#  775   HOP_gd_96      float64
#  776   HOP_hb_96      float64
#  777   EAR_left_97    float64
#  778   EAR_right_97   float64
#  779   EAR_mean_97    float64
#  780   MAR_97         float64
#  781   EBR_97         int64
#  782   PERCLOS_97     float64
#  783   HOP_gd_97      float64
#  784   HOP_hb_97      float64
#  785   EAR_left_98    float64
#  786   EAR_right_98   float64
#  787   EAR_mean_98    float64
#  788   MAR_98         float64
#  789   EBR_98         int64
#  790   PERCLOS_98     float64
#  791   HOP_gd_98      float64
#  792   HOP_hb_98      float64
#  793   EAR_left_99    float64
#  794   EAR_right_99   float64
#  795   EAR_mean_99    float64
#  796   MAR_99         float64
#  797   EBR_99         int64
#  798   PERCLOS_99     float64
#  799   HOP_gd_99      float64
#  800   HOP_hb_99      float64
#  801   EAR_left_100   float64
#  802   EAR_right_100  float64
#  803   EAR_mean_100   float64
#  804   MAR_100        float64
#  805   EBR_100        int64
#  806   PERCLOS_100    float64
#  807   HOP_gd_100     float64
#  808   HOP_hb_100     float64
#  809   EAR_left_101   float64
#  810   EAR_right_101  float64
#  811   EAR_mean_101   float64
#  812   MAR_101        float64
#  813   EBR_101        int64
#  814   PERCLOS_101    float64
#  815   HOP_gd_101     float64
#  816   HOP_hb_101     float64
#  817   EAR_left_102   float64
#  818   EAR_right_102  float64
#  819   EAR_mean_102   float64
#  820   MAR_102        float64
#  821   EBR_102        int64
#  822   PERCLOS_102    float64
#  823   HOP_gd_102     float64
#  824   HOP_hb_102     float64
#  825   EAR_left_103   float64
#  826   EAR_right_103  float64
#  827   EAR_mean_103   float64
#  828   MAR_103        float64
#  829   EBR_103        int64
#  830   PERCLOS_103    float64
#  831   HOP_gd_103     float64
#  832   HOP_hb_103     float64
#  833   EAR_left_104   float64
#  834   EAR_right_104  float64
#  835   EAR_mean_104   float64
#  836   MAR_104        float64
#  837   EBR_104        int64
#  838   PERCLOS_104    float64
#  839   HOP_gd_104     float64
#  840   HOP_hb_104     float64
#  841   EAR_left_105   float64
#  842   EAR_right_105  float64
#  843   EAR_mean_105   float64
#  844   MAR_105        float64
#  845   EBR_105        int64
#  846   PERCLOS_105    float64
#  847   HOP_gd_105     float64
#  848   HOP_hb_105     float64
#  849   EAR_left_106   float64
#  850   EAR_right_106  float64
#  851   EAR_mean_106   float64
#  852   MAR_106        float64
#  853   EBR_106        int64
#  854   PERCLOS_106    float64
#  855   HOP_gd_106     float64
#  856   HOP_hb_106     float64
#  857   EAR_left_107   float64
#  858   EAR_right_107  float64
#  859   EAR_mean_107   float64
#  860   MAR_107        float64
#  861   EBR_107        int64
#  862   PERCLOS_107    float64
#  863   HOP_gd_107     float64
#  864   HOP_hb_107     float64
#  865   EAR_left_108   float64
#  866   EAR_right_108  float64
#  867   EAR_mean_108   float64
#  868   MAR_108        float64
#  869   EBR_108        int64
#  870   PERCLOS_108    float64
#  871   HOP_gd_108     float64
#  872   HOP_hb_108     float64
#  873   EAR_left_109   float64
#  874   EAR_right_109  float64
#  875   EAR_mean_109   float64
#  876   MAR_109        float64
#  877   EBR_109        int64
#  878   PERCLOS_109    float64
#  879   HOP_gd_109     float64
#  880   HOP_hb_109     float64
#  881   EAR_left_110   float64
#  882   EAR_right_110  float64
#  883   EAR_mean_110   float64
#  884   MAR_110        float64
#  885   EBR_110        int64
#  886   PERCLOS_110    float64
#  887   HOP_gd_110     float64
#  888   HOP_hb_110     float64
#  889   EAR_left_111   float64
#  890   EAR_right_111  float64
#  891   EAR_mean_111   float64
#  892   MAR_111        float64
#  893   EBR_111        int64
#  894   PERCLOS_111    float64
#  895   HOP_gd_111     float64
#  896   HOP_hb_111     float64
#  897   EAR_left_112   float64
#  898   EAR_right_112  float64
#  899   EAR_mean_112   float64
#  900   MAR_112        float64
#  901   EBR_112        int64
#  902   PERCLOS_112    float64
#  903   HOP_gd_112     float64
#  904   HOP_hb_112     float64
#  905   EAR_left_113   float64
#  906   EAR_right_113  float64
#  907   EAR_mean_113   float64
#  908   MAR_113        float64
#  909   EBR_113        int64
#  910   PERCLOS_113    float64
#  911   HOP_gd_113     float64
#  912   HOP_hb_113     float64
#  913   EAR_left_114   float64
#  914   EAR_right_114  float64
#  915   EAR_mean_114   float64
#  916   MAR_114        float64
#  917   EBR_114        int64
#  918   PERCLOS_114    float64
#  919   HOP_gd_114     float64
#  920   HOP_hb_114     float64
#  921   EAR_left_115   float64
#  922   EAR_right_115  float64
#  923   EAR_mean_115   float64
#  924   MAR_115        float64
#  925   EBR_115        int64
#  926   PERCLOS_115    float64
#  927   HOP_gd_115     float64
#  928   HOP_hb_115     float64
#  929   EAR_left_116   float64
#  930   EAR_right_116  float64
#  931   EAR_mean_116   float64
#  932   MAR_116        float64
#  933   EBR_116        int64
#  934   PERCLOS_116    float64
#  935   HOP_gd_116     float64
#  936   HOP_hb_116     float64
#  937   EAR_left_117   float64
#  938   EAR_right_117  float64
#  939   EAR_mean_117   float64
#  940   MAR_117        float64
#  941   EBR_117        int64
#  942   PERCLOS_117    float64
#  943   HOP_gd_117     float64
#  944   HOP_hb_117     float64
#  945   EAR_left_118   float64
#  946   EAR_right_118  float64
#  947   EAR_mean_118   float64
#  948   MAR_118        float64
#  949   EBR_118        int64
#  950   PERCLOS_118    float64
#  951   HOP_gd_118     float64
#  952   HOP_hb_118     float64
#  953   EAR_left_119   float64
#  954   EAR_right_119  float64
#  955   EAR_mean_119   float64
#  956   MAR_119        float64
#  957   EBR_119        int64
#  958   PERCLOS_119    float64
#  959   HOP_gd_119     float64
#  960   HOP_hb_119     float64
#  961   EAR_left_120   float64
#  962   EAR_right_120  float64
#  963   EAR_mean_120   float64
#  964   MAR_120        float64
#  965   EBR_120        int64
#  966   PERCLOS_120    float64
#  967   HOP_gd_120     float64
#  968   HOP_hb_120     float64
#  969   EAR_left_121   float64
#  970   EAR_right_121  float64
#  971   EAR_mean_121   float64
#  972   MAR_121        float64
#  973   EBR_121        int64
#  974   PERCLOS_121    float64
#  975   HOP_gd_121     float64
#  976   HOP_hb_121     float64
#  977   EAR_left_122   float64
#  978   EAR_right_122  float64
#  979   EAR_mean_122   float64
#  980   MAR_122        float64
#  981   EBR_122        int64
#  982   PERCLOS_122    float64
#  983   HOP_gd_122     float64
#  984   HOP_hb_122     float64
#  985   EAR_left_123   float64
#  986   EAR_right_123  float64
#  987   EAR_mean_123   float64
#  988   MAR_123        float64
#  989   EBR_123        int64
#  990   PERCLOS_123    float64
#  991   HOP_gd_123     float64
#  992   HOP_hb_123     float64
#  993   EAR_left_124   float64
#  994   EAR_right_124  float64
#  995   EAR_mean_124   float64
#  996   MAR_124        float64
#  997   EBR_124        int64
#  998   PERCLOS_124    float64
#  999   HOP_gd_124     float64
#  1000  HOP_hb_124     float64
#  1001  EAR_left_125   float64
#  1002  EAR_right_125  float64
#  1003  EAR_mean_125   float64
#  1004  MAR_125        float64
#  1005  EBR_125        int64
#  1006  PERCLOS_125    float64
#  1007  HOP_gd_125     float64
#  1008  HOP_hb_125     float64
#  1009  EAR_left_126   float64
#  1010  EAR_right_126  float64
#  1011  EAR_mean_126   float64
#  1012  MAR_126        float64
#  1013  EBR_126        int64
#  1014  PERCLOS_126    float64
#  1015  HOP_gd_126     float64
#  1016  HOP_hb_126     float64
#  1017  EAR_left_127   float64
#  1018  EAR_right_127  float64
#  1019  EAR_mean_127   float64
#  1020  MAR_127        float64
#  1021  EBR_127        int64
#  1022  PERCLOS_127    float64
#  1023  HOP_gd_127     float64
#  1024  HOP_hb_127     float64
#  1025  EAR_left_128   float64
#  1026  EAR_right_128  float64
#  1027  EAR_mean_128   float64
#  1028  MAR_128        float64
#  1029  EBR_128        int64
#  1030  PERCLOS_128    float64
#  1031  HOP_gd_128     float64
#  1032  HOP_hb_128     float64
#  1033  EAR_left_129   float64
#  1034  EAR_right_129  float64
#  1035  EAR_mean_129   float64
#  1036  MAR_129        float64
#  1037  EBR_129        int64
#  1038  PERCLOS_129    float64
#  1039  HOP_gd_129     float64
#  1040  HOP_hb_129     float64
#  1041  EAR_left_130   float64
#  1042  EAR_right_130  float64
#  1043  EAR_mean_130   float64
#  1044  MAR_130        float64
#  1045  EBR_130        int64
#  1046  PERCLOS_130    float64
#  1047  HOP_gd_130     float64
#  1048  HOP_hb_130     float64
#  1049  EAR_left_131   float64
#  1050  EAR_right_131  float64
#  1051  EAR_mean_131   float64
#  1052  MAR_131        float64
#  1053  EBR_131        int64
#  1054  PERCLOS_131    float64
#  1055  HOP_gd_131     float64
#  1056  HOP_hb_131     float64
#  1057  EAR_left_132   float64
#  1058  EAR_right_132  float64
#  1059  EAR_mean_132   float64
#  1060  MAR_132        float64
#  1061  EBR_132        int64
#  1062  PERCLOS_132    float64
#  1063  HOP_gd_132     float64
#  1064  HOP_hb_132     float64
#  1065  EAR_left_133   float64
#  1066  EAR_right_133  float64
#  1067  EAR_mean_133   float64
#  1068  MAR_133        float64
#  1069  EBR_133        int64
#  1070  PERCLOS_133    float64
#  1071  HOP_gd_133     float64
#  1072  HOP_hb_133     float64
#  1073  EAR_left_134   float64
#  1074  EAR_right_134  float64
#  1075  EAR_mean_134   float64
#  1076  MAR_134        float64
#  1077  EBR_134        int64
#  1078  PERCLOS_134    float64
#  1079  HOP_gd_134     float64
#  1080  HOP_hb_134     float64
#  1081  EAR_left_135   float64
#  1082  EAR_right_135  float64
#  1083  EAR_mean_135   float64
#  1084  MAR_135        float64
#  1085  EBR_135        int64
#  1086  PERCLOS_135    float64
#  1087  HOP_gd_135     float64
#  1088  HOP_hb_135     float64
#  1089  EAR_left_136   float64
#  1090  EAR_right_136  float64
#  1091  EAR_mean_136   float64
#  1092  MAR_136        float64
#  1093  EBR_136        int64
#  1094  PERCLOS_136    float64
#  1095  HOP_gd_136     float64
#  1096  HOP_hb_136     float64
#  1097  EAR_left_137   float64
#  1098  EAR_right_137  float64
#  1099  EAR_mean_137   float64
#  1100  MAR_137        float64
#  1101  EBR_137        int64
#  1102  PERCLOS_137    float64
#  1103  HOP_gd_137     float64
#  1104  HOP_hb_137     float64
#  1105  EAR_left_138   float64
#  1106  EAR_right_138  float64
#  1107  EAR_mean_138   float64
#  1108  MAR_138        float64
#  1109  EBR_138        int64
#  1110  PERCLOS_138    float64
#  1111  HOP_gd_138     float64
#  1112  HOP_hb_138     float64
#  1113  EAR_left_139   float64
#  1114  EAR_right_139  float64
#  1115  EAR_mean_139   float64
#  1116  MAR_139        float64
#  1117  EBR_139        int64
#  1118  PERCLOS_139    float64
#  1119  HOP_gd_139     float64
#  1120  HOP_hb_139     float64
#  1121  EAR_left_140   float64
#  1122  EAR_right_140  float64
#  1123  EAR_mean_140   float64
#  1124  MAR_140        float64
#  1125  EBR_140        int64
#  1126  PERCLOS_140    float64
#  1127  HOP_gd_140     float64
#  1128  HOP_hb_140     float64
#  1129  EAR_left_141   float64
#  1130  EAR_right_141  float64
#  1131  EAR_mean_141   float64
#  1132  MAR_141        float64
#  1133  EBR_141        int64
#  1134  PERCLOS_141    float64
#  1135  HOP_gd_141     float64
#  1136  HOP_hb_141     float64
#  1137  EAR_left_142   float64
#  1138  EAR_right_142  float64
#  1139  EAR_mean_142   float64
#  1140  MAR_142        float64
#  1141  EBR_142        int64
#  1142  PERCLOS_142    float64
#  1143  HOP_gd_142     float64
#  1144  HOP_hb_142     float64
#  1145  EAR_left_143   float64
#  1146  EAR_right_143  float64
#  1147  EAR_mean_143   float64
#  1148  MAR_143        float64
#  1149  EBR_143        int64
#  1150  PERCLOS_143    float64
#  1151  HOP_gd_143     float64
#  1152  HOP_hb_143     float64
#  1153  EAR_left_144   float64
#  1154  EAR_right_144  float64
#  1155  EAR_mean_144   float64
#  1156  MAR_144        float64
#  1157  EBR_144        int64
#  1158  PERCLOS_144    float64
#  1159  HOP_gd_144     float64
#  1160  HOP_hb_144     float64
#  1161  EAR_left_145   float64
#  1162  EAR_right_145  float64
#  1163  EAR_mean_145   float64
#  1164  MAR_145        float64
#  1165  EBR_145        int64
#  1166  PERCLOS_145    float64
#  1167  HOP_gd_145     float64
#  1168  HOP_hb_145     float64
#  1169  EAR_left_146   float64
#  1170  EAR_right_146  float64
#  1171  EAR_mean_146   float64
#  1172  MAR_146        float64
#  1173  EBR_146        int64
#  1174  PERCLOS_146    float64
#  1175  HOP_gd_146     float64
#  1176  HOP_hb_146     float64
#  1177  EAR_left_147   float64
#  1178  EAR_right_147  float64
#  1179  EAR_mean_147   float64
#  1180  MAR_147        float64
#  1181  EBR_147        int64
#  1182  PERCLOS_147    float64
#  1183  HOP_gd_147     float64
#  1184  HOP_hb_147     float64
#  1185  EAR_left_148   float64
#  1186  EAR_right_148  float64
#  1187  EAR_mean_148   float64
#  1188  MAR_148        float64
#  1189  EBR_148        int64
#  1190  PERCLOS_148    float64
#  1191  HOP_gd_148     float64
#  1192  HOP_hb_148     float64
#  1193  EAR_left_149   float64
#  1194  EAR_right_149  float64
#  1195  EAR_mean_149   float64
#  1196  MAR_149        float64
#  1197  EBR_149        int64
#  1198  PERCLOS_149    float64
#  1199  HOP_gd_149     float64
#  1200  HOP_hb_149     float64
#  1201  EAR_left_150   float64
#  1202  EAR_right_150  float64
#  1203  EAR_mean_150   float64
#  1204  MAR_150        float64
#  1205  EBR_150        int64
#  1206  PERCLOS_150    float64
#  1207  HOP_gd_150     float64
#  1208  HOP_hb_150     float64
#  1209  EAR_left_151   float64
#  1210  EAR_right_151  float64
#  1211  EAR_mean_151   float64
#  1212  MAR_151        float64
#  1213  EBR_151        int64
#  1214  PERCLOS_151    float64
#  1215  HOP_gd_151     float64
#  1216  HOP_hb_151     float64
#  1217  EAR_left_152   float64
#  1218  EAR_right_152  float64
#  1219  EAR_mean_152   float64
#  1220  MAR_152        float64
#  1221  EBR_152        int64
#  1222  PERCLOS_152    float64
#  1223  HOP_gd_152     float64
#  1224  HOP_hb_152     float64
#  1225  EAR_left_153   float64
#  1226  EAR_right_153  float64
#  1227  EAR_mean_153   float64
#  1228  MAR_153        float64
#  1229  EBR_153        int64
#  1230  PERCLOS_153    float64
#  1231  HOP_gd_153     float64
#  1232  HOP_hb_153     float64
#  1233  EAR_left_154   float64
#  1234  EAR_right_154  float64
#  1235  EAR_mean_154   float64
#  1236  MAR_154        float64
#  1237  EBR_154        int64
#  1238  PERCLOS_154    float64
#  1239  HOP_gd_154     float64
#  1240  HOP_hb_154     float64
#  1241  EAR_left_155   float64
#  1242  EAR_right_155  float64
#  1243  EAR_mean_155   float64
#  1244  MAR_155        float64
#  1245  EBR_155        int64
#  1246  PERCLOS_155    float64
#  1247  HOP_gd_155     float64
#  1248  HOP_hb_155     float64
#  1249  EAR_left_156   float64
#  1250  EAR_right_156  float64
#  1251  EAR_mean_156   float64
#  1252  MAR_156        float64
#  1253  EBR_156        int64
#  1254  PERCLOS_156    float64
#  1255  HOP_gd_156     float64
#  1256  HOP_hb_156     float64
#  1257  EAR_left_157   float64
#  1258  EAR_right_157  float64
#  1259  EAR_mean_157   float64
#  1260  MAR_157        float64
#  1261  EBR_157        int64
#  1262  PERCLOS_157    float64
#  1263  HOP_gd_157     float64
#  1264  HOP_hb_157     float64
#  1265  EAR_left_158   float64
#  1266  EAR_right_158  float64
#  1267  EAR_mean_158   float64
#  1268  MAR_158        float64
#  1269  EBR_158        int64
#  1270  PERCLOS_158    float64
#  1271  HOP_gd_158     float64
#  1272  HOP_hb_158     float64
#  1273  EAR_left_159   float64
#  1274  EAR_right_159  float64
#  1275  EAR_mean_159   float64
#  1276  MAR_159        float64
#  1277  EBR_159        int64
#  1278  PERCLOS_159    float64
#  1279  HOP_gd_159     float64
#  1280  HOP_hb_159     float64
#  1281  EAR_left_160   float64
#  1282  EAR_right_160  float64
#  1283  EAR_mean_160   float64
#  1284  MAR_160        float64
#  1285  EBR_160        int64
#  1286  PERCLOS_160    float64
#  1287  HOP_gd_160     float64
#  1288  HOP_hb_160     float64
#  1289  EAR_left_161   float64
#  1290  EAR_right_161  float64
#  1291  EAR_mean_161   float64
#  1292  MAR_161        float64
#  1293  EBR_161        int64
#  1294  PERCLOS_161    float64
#  1295  HOP_gd_161     float64
#  1296  HOP_hb_161     float64
#  1297  EAR_left_162   float64
#  1298  EAR_right_162  float64
#  1299  EAR_mean_162   float64
#  1300  MAR_162        float64
#  1301  EBR_162        int64
#  1302  PERCLOS_162    float64
#  1303  HOP_gd_162     float64
#  1304  HOP_hb_162     float64
#  1305  EAR_left_163   float64
#  1306  EAR_right_163  float64
#  1307  EAR_mean_163   float64
#  1308  MAR_163        float64
#  1309  EBR_163        int64
#  1310  PERCLOS_163    float64
#  1311  HOP_gd_163     float64
#  1312  HOP_hb_163     float64
#  1313  EAR_left_164   float64
#  1314  EAR_right_164  float64
#  1315  EAR_mean_164   float64
#  1316  MAR_164        float64
#  1317  EBR_164        int64
#  1318  PERCLOS_164    float64
#  1319  HOP_gd_164     float64
#  1320  HOP_hb_164     float64
#  1321  EAR_left_165   float64
#  1322  EAR_right_165  float64
#  1323  EAR_mean_165   float64
#  1324  MAR_165        float64
#  1325  EBR_165        int64
#  1326  PERCLOS_165    float64
#  1327  HOP_gd_165     float64
#  1328  HOP_hb_165     float64
#  1329  EAR_left_166   float64
#  1330  EAR_right_166  float64
#  1331  EAR_mean_166   float64
#  1332  MAR_166        float64
#  1333  EBR_166        int64
#  1334  PERCLOS_166    float64
#  1335  HOP_gd_166     float64
#  1336  HOP_hb_166     float64
#  1337  EAR_left_167   float64
#  1338  EAR_right_167  float64
#  1339  EAR_mean_167   float64
#  1340  MAR_167        float64
#  1341  EBR_167        int64
#  1342  PERCLOS_167    float64
#  1343  HOP_gd_167     float64
#  1344  HOP_hb_167     float64
#  1345  EAR_left_168   float64
#  1346  EAR_right_168  float64
#  1347  EAR_mean_168   float64
#  1348  MAR_168        float64
#  1349  EBR_168        int64
#  1350  PERCLOS_168    float64
#  1351  HOP_gd_168     float64
#  1352  HOP_hb_168     float64
#  1353  EAR_left_169   float64
#  1354  EAR_right_169  float64
#  1355  EAR_mean_169   float64
#  1356  MAR_169        float64
#  1357  EBR_169        int64
#  1358  PERCLOS_169    float64
#  1359  HOP_gd_169     float64
#  1360  HOP_hb_169     float64
#  1361  EAR_left_170   float64
#  1362  EAR_right_170  float64
#  1363  EAR_mean_170   float64
#  1364  MAR_170        float64
#  1365  EBR_170        int64
#  1366  PERCLOS_170    float64
#  1367  HOP_gd_170     float64
#  1368  HOP_hb_170     float64
#  1369  EAR_left_171   float64
#  1370  EAR_right_171  float64
#  1371  EAR_mean_171   float64
#  1372  MAR_171        float64
#  1373  EBR_171        int64
#  1374  PERCLOS_171    float64
#  1375  HOP_gd_171     float64
#  1376  HOP_hb_171     float64
#  1377  EAR_left_172   float64
#  1378  EAR_right_172  float64
#  1379  EAR_mean_172   float64
#  1380  MAR_172        float64
#  1381  EBR_172        int64
#  1382  PERCLOS_172    float64
#  1383  HOP_gd_172     float64
#  1384  HOP_hb_172     float64
#  1385  EAR_left_173   float64
#  1386  EAR_right_173  float64
#  1387  EAR_mean_173   float64
#  1388  MAR_173        float64
#  1389  EBR_173        int64
#  1390  PERCLOS_173    float64
#  1391  HOP_gd_173     float64
#  1392  HOP_hb_173     float64
#  1393  EAR_left_174   float64
#  1394  EAR_right_174  float64
#  1395  EAR_mean_174   float64
#  1396  MAR_174        float64
#  1397  EBR_174        int64
#  1398  PERCLOS_174    float64
#  1399  HOP_gd_174     float64
#  1400  HOP_hb_174     float64
#  1401  EAR_left_175   float64
#  1402  EAR_right_175  float64
#  1403  EAR_mean_175   float64
#  1404  MAR_175        float64
#  1405  EBR_175        int64
#  1406  PERCLOS_175    float64
#  1407  HOP_gd_175     float64
#  1408  HOP_hb_175     float64
#  1409  EAR_left_176   float64
#  1410  EAR_right_176  float64
#  1411  EAR_mean_176   float64
#  1412  MAR_176        float64
#  1413  EBR_176        int64
#  1414  PERCLOS_176    float64
#  1415  HOP_gd_176     float64
#  1416  HOP_hb_176     float64
#  1417  EAR_left_177   float64
#  1418  EAR_right_177  float64
#  1419  EAR_mean_177   float64
#  1420  MAR_177        float64
#  1421  EBR_177        int64
#  1422  PERCLOS_177    float64
#  1423  HOP_gd_177     float64
#  1424  HOP_hb_177     float64
#  1425  EAR_left_178   float64
#  1426  EAR_right_178  float64
#  1427  EAR_mean_178   float64
#  1428  MAR_178        float64
#  1429  EBR_178        int64
#  1430  PERCLOS_178    float64
#  1431  HOP_gd_178     float64
#  1432  HOP_hb_178     float64
#  1433  EAR_left_179   float64
#  1434  EAR_right_179  float64
#  1435  EAR_mean_179   float64
#  1436  MAR_179        float64
#  1437  EBR_179        int64
#  1438  PERCLOS_179    float64
#  1439  HOP_gd_179     float64
#  1440  HOP_hb_179     float64
#  1441  EAR_left_180   float64
#  1442  EAR_right_180  float64
#  1443  EAR_mean_180   float64
#  1444  MAR_180        float64
#  1445  EBR_180        int64
#  1446  PERCLOS_180    float64
#  1447  HOP_gd_180     float64
#  1448  HOP_hb_180     float64
#  1449  EAR_left_181   float64
#  1450  EAR_right_181  float64
#  1451  EAR_mean_181   float64
#  1452  MAR_181        float64
#  1453  EBR_181        int64
#  1454  PERCLOS_181    float64
#  1455  HOP_gd_181     float64
#  1456  HOP_hb_181     float64
#  1457  EAR_left_182   float64
#  1458  EAR_right_182  float64
#  1459  EAR_mean_182   float64
#  1460  MAR_182        float64
#  1461  EBR_182        int64
#  1462  PERCLOS_182    float64
#  1463  HOP_gd_182     float64
#  1464  HOP_hb_182     float64
#  1465  EAR_left_183   float64
#  1466  EAR_right_183  float64
#  1467  EAR_mean_183   float64
#  1468  MAR_183        float64
#  1469  EBR_183        int64
#  1470  PERCLOS_183    float64
#  1471  HOP_gd_183     float64
#  1472  HOP_hb_183     float64
#  1473  EAR_left_184   float64
#  1474  EAR_right_184  float64
#  1475  EAR_mean_184   float64
#  1476  MAR_184        float64
#  1477  EBR_184        int64
#  1478  PERCLOS_184    float64
#  1479  HOP_gd_184     float64
#  1480  HOP_hb_184     float64
#  1481  EAR_left_185   float64
#  1482  EAR_right_185  float64
#  1483  EAR_mean_185   float64
#  1484  MAR_185        float64
#  1485  EBR_185        int64
#  1486  PERCLOS_185    float64
#  1487  HOP_gd_185     float64
#  1488  HOP_hb_185     float64
#  1489  EAR_left_186   float64
#  1490  EAR_right_186  float64
#  1491  EAR_mean_186   float64
#  1492  MAR_186        float64
#  1493  EBR_186        int64
#  1494  PERCLOS_186    float64
#  1495  HOP_gd_186     float64
#  1496  HOP_hb_186     float64
#  1497  EAR_left_187   float64
#  1498  EAR_right_187  float64
#  1499  EAR_mean_187   float64
#  1500  MAR_187        float64
#  1501  EBR_187        int64
#  1502  PERCLOS_187    float64
#  1503  HOP_gd_187     float64
#  1504  HOP_hb_187     float64
#  1505  EAR_left_188   float64
#  1506  EAR_right_188  float64
#  1507  EAR_mean_188   float64
#  1508  MAR_188        float64
#  1509  EBR_188        int64
#  1510  PERCLOS_188    float64
#  1511  HOP_gd_188     float64
#  1512  HOP_hb_188     float64
#  1513  EAR_left_189   float64
#  1514  EAR_right_189  float64
#  1515  EAR_mean_189   float64
#  1516  MAR_189        float64
#  1517  EBR_189        int64
#  1518  PERCLOS_189    float64
#  1519  HOP_gd_189     float64
#  1520  HOP_hb_189     float64
#  1521  EAR_left_190   float64
#  1522  EAR_right_190  float64
#  1523  EAR_mean_190   float64
#  1524  MAR_190        float64
#  1525  EBR_190        int64
#  1526  PERCLOS_190    float64
#  1527  HOP_gd_190     float64
#  1528  HOP_hb_190     float64
#  1529  EAR_left_191   float64
#  1530  EAR_right_191  float64
#  1531  EAR_mean_191   float64
#  1532  MAR_191        float64
#  1533  EBR_191        int64
#  1534  PERCLOS_191    float64
#  1535  HOP_gd_191     float64
#  1536  HOP_hb_191     float64
#  1537  EAR_left_192   float64
#  1538  EAR_right_192  float64
#  1539  EAR_mean_192   float64
#  1540  MAR_192        float64
#  1541  EBR_192        int64
#  1542  PERCLOS_192    float64
#  1543  HOP_gd_192     float64
#  1544  HOP_hb_192     float64
#  1545  EAR_left_193   float64
#  1546  EAR_right_193  float64
#  1547  EAR_mean_193   float64
#  1548  MAR_193        float64
#  1549  EBR_193        int64
#  1550  PERCLOS_193    float64
#  1551  HOP_gd_193     float64
#  1552  HOP_hb_193     float64
#  1553  EAR_left_194   float64
#  1554  EAR_right_194  float64
#  1555  EAR_mean_194   float64
#  1556  MAR_194        float64
#  1557  EBR_194        int64
#  1558  PERCLOS_194    float64
#  1559  HOP_gd_194     float64
#  1560  HOP_hb_194     float64
#  1561  EAR_left_195   float64
#  1562  EAR_right_195  float64
#  1563  EAR_mean_195   float64
#  1564  MAR_195        float64
#  1565  EBR_195        int64
#  1566  PERCLOS_195    float64
#  1567  HOP_gd_195     float64
#  1568  HOP_hb_195     float64
#  1569  EAR_left_196   float64
#  1570  EAR_right_196  float64
#  1571  EAR_mean_196   float64
#  1572  MAR_196        float64
#  1573  EBR_196        int64
#  1574  PERCLOS_196    float64
#  1575  HOP_gd_196     float64
#  1576  HOP_hb_196     float64
#  1577  EAR_left_197   float64
#  1578  EAR_right_197  float64
#  1579  EAR_mean_197   float64
#  1580  MAR_197        float64
#  1581  EBR_197        int64
#  1582  PERCLOS_197    float64
#  1583  HOP_gd_197     float64
#  1584  HOP_hb_197     float64
#  1585  EAR_left_198   float64
#  1586  EAR_right_198  float64
#  1587  EAR_mean_198   float64
#  1588  MAR_198        float64
#  1589  EBR_198        int64
#  1590  PERCLOS_198    float64
#  1591  HOP_gd_198     float64
#  1592  HOP_hb_198     float64
#  1593  EAR_left_199   float64
# ...
#  6471  HOP_gd_808     float64
#  6472  HOP_hb_808     float64
#  6473  EAR_left_809   float64
#  6474  EAR_right_809  float64
#  6475  EAR_mean_809   float64
#  6476  MAR_809        float64
#  6477  EBR_809        int64
#  6478  PERCLOS_809    float64
#  6479  HOP_gd_809     float64
#  6480  HOP_hb_809     float64
#  6481  EAR_left_810   float64
#  6482  EAR_right_810  float64
#  6483  EAR_mean_810   float64
#  6484  MAR_810        float64
#  6485  EBR_810        int64
#  6486  PERCLOS_810    float64
#  6487  HOP_gd_810     float64
#  6488  HOP_hb_810     float64
#  6489  EAR_left_811   float64
#  6490  EAR_right_811  float64
#  6491  EAR_mean_811   float64
#  6492  MAR_811        float64
#  6493  EBR_811        int64
#  6494  PERCLOS_811    float64
#  6495  HOP_gd_811     float64
#  6496  HOP_hb_811     float64
#  6497  EAR_left_812   float64
#  6498  EAR_right_812  float64
#  6499  EAR_mean_812   float64
#  6500  MAR_812        float64
#  6501  EBR_812        int64
#  6502  PERCLOS_812    float64
#  6503  HOP_gd_812     float64
#  6504  HOP_hb_812     float64
#  6505  EAR_left_813   float64
#  6506  EAR_right_813  float64
#  6507  EAR_mean_813   float64
#  6508  MAR_813        float64
#  6509  EBR_813        int64
#  6510  PERCLOS_813    float64
#  6511  HOP_gd_813     float64
#  6512  HOP_hb_813     float64
#  6513  EAR_left_814   float64
#  6514  EAR_right_814  float64
#  6515  EAR_mean_814   float64
#  6516  MAR_814        float64
#  6517  EBR_814        int64
#  6518  PERCLOS_814    float64
#  6519  HOP_gd_814     float64
#  6520  HOP_hb_814     float64
#  6521  EAR_left_815   float64
#  6522  EAR_right_815  float64
#  6523  EAR_mean_815   float64
#  6524  MAR_815        float64
#  6525  EBR_815        int64
#  6526  PERCLOS_815    float64
#  6527  HOP_gd_815     float64
#  6528  HOP_hb_815     float64
#  6529  EAR_left_816   float64
#  6530  EAR_right_816  float64
#  6531  EAR_mean_816   float64
#  6532  MAR_816        float64
#  6533  EBR_816        int64
#  6534  PERCLOS_816    float64
#  6535  HOP_gd_816     float64
#  6536  HOP_hb_816     float64
#  6537  EAR_left_817   float64
#  6538  EAR_right_817  float64
#  6539  EAR_mean_817   float64
#  6540  MAR_817        float64
#  6541  EBR_817        int64
#  6542  PERCLOS_817    float64
#  6543  HOP_gd_817     float64
#  6544  HOP_hb_817     float64
#  6545  EAR_left_818   float64
#  6546  EAR_right_818  float64
#  6547  EAR_mean_818   float64
#  6548  MAR_818        float64
#  6549  EBR_818        int64
#  6550  PERCLOS_818    float64
#  6551  HOP_gd_818     float64
#  6552  HOP_hb_818     float64
#  6553  EAR_left_819   float64
#  6554  EAR_right_819  float64
#  6555  EAR_mean_819   float64
#  6556  MAR_819        float64
#  6557  EBR_819        int64
#  6558  PERCLOS_819    float64
#  6559  HOP_gd_819     float64
#  6560  HOP_hb_819     float64
#  6561  EAR_left_820   float64
#  6562  EAR_right_820  float64
#  6563  EAR_mean_820   float64
#  6564  MAR_820        float64
#  6565  EBR_820        int64
#  6566  PERCLOS_820    float64
#  6567  HOP_gd_820     float64
#  6568  HOP_hb_820     float64
#  6569  EAR_left_821   float64
#  6570  EAR_right_821  float64
#  6571  EAR_mean_821   float64
#  6572  MAR_821        float64
#  6573  EBR_821        int64
#  6574  PERCLOS_821    float64
#  6575  HOP_gd_821     float64
#  6576  HOP_hb_821     float64
#  6577  EAR_left_822   float64
#  6578  EAR_right_822  float64
#  6579  EAR_mean_822   float64
#  6580  MAR_822        float64
#  6581  EBR_822        int64
#  6582  PERCLOS_822    float64
#  6583  HOP_gd_822     float64
#  6584  HOP_hb_822     float64
#  6585  EAR_left_823   float64
#  6586  EAR_right_823  float64
#  6587  EAR_mean_823   float64
#  6588  MAR_823        float64
#  6589  EBR_823        int64
#  6590  PERCLOS_823    float64
#  6591  HOP_gd_823     float64
#  6592  HOP_hb_823     float64
#  6593  EAR_left_824   float64
#  6594  EAR_right_824  float64
#  6595  EAR_mean_824   float64
#  6596  MAR_824        float64
#  6597  EBR_824        int64
#  6598  PERCLOS_824    float64
#  6599  HOP_gd_824     float64
#  6600  HOP_hb_824     float64
#  6601  EAR_left_825   float64
#  6602  EAR_right_825  float64
#  6603  EAR_mean_825   float64
#  6604  MAR_825        float64
#  6605  EBR_825        int64
#  6606  PERCLOS_825    float64
#  6607  HOP_gd_825     float64
#  6608  HOP_hb_825     float64
#  6609  EAR_left_826   float64
#  6610  EAR_right_826  float64
#  6611  EAR_mean_826   float64
#  6612  MAR_826        float64
#  6613  EBR_826        int64
#  6614  PERCLOS_826    float64
#  6615  HOP_gd_826     float64
#  6616  HOP_hb_826     float64
#  6617  EAR_left_827   float64
#  6618  EAR_right_827  float64
#  6619  EAR_mean_827   float64
#  6620  MAR_827        float64
#  6621  EBR_827        int64
#  6622  PERCLOS_827    float64
#  6623  HOP_gd_827     float64
#  6624  HOP_hb_827     float64
#  6625  EAR_left_828   float64
#  6626  EAR_right_828  float64
#  6627  EAR_mean_828   float64
#  6628  MAR_828        float64
#  6629  EBR_828        int64
#  6630  PERCLOS_828    float64
#  6631  HOP_gd_828     float64
#  6632  HOP_hb_828     float64
#  6633  EAR_left_829   float64
#  6634  EAR_right_829  float64
#  6635  EAR_mean_829   float64
#  6636  MAR_829        float64
#  6637  EBR_829        int64
#  6638  PERCLOS_829    float64
#  6639  HOP_gd_829     float64
#  6640  HOP_hb_829     float64
#  6641  EAR_left_830   float64
#  6642  EAR_right_830  float64
#  6643  EAR_mean_830   float64
#  6644  MAR_830        float64
#  6645  EBR_830        int64
#  6646  PERCLOS_830    float64
#  6647  HOP_gd_830     float64
#  6648  HOP_hb_830     float64
#  6649  EAR_left_831   float64
#  6650  EAR_right_831  float64
#  6651  EAR_mean_831   float64
#  6652  MAR_831        float64
#  6653  EBR_831        int64
#  6654  PERCLOS_831    float64
#  6655  HOP_gd_831     float64
#  6656  HOP_hb_831     float64
#  6657  EAR_left_832   float64
#  6658  EAR_right_832  float64
#  6659  EAR_mean_832   float64
#  6660  MAR_832        float64
#  6661  EBR_832        int64
#  6662  PERCLOS_832    float64
#  6663  HOP_gd_832     float64
#  6664  HOP_hb_832     float64
#  6665  EAR_left_833   float64
#  6666  EAR_right_833  float64
#  6667  EAR_mean_833   float64
#  6668  MAR_833        float64
#  6669  EBR_833        int64
#  6670  PERCLOS_833    float64
#  6671  HOP_gd_833     float64
#  6672  HOP_hb_833     float64
#  6673  EAR_left_834   float64
#  6674  EAR_right_834  float64
#  6675  EAR_mean_834   float64
#  6676  MAR_834        float64
#  6677  EBR_834        int64
#  6678  PERCLOS_834    float64
#  6679  HOP_gd_834     float64
#  6680  HOP_hb_834     float64
#  6681  EAR_left_835   float64
#  6682  EAR_right_835  float64
#  6683  EAR_mean_835   float64
#  6684  MAR_835        float64
#  6685  EBR_835        int64
#  6686  PERCLOS_835    float64
#  6687  HOP_gd_835     float64
#  6688  HOP_hb_835     float64
#  6689  EAR_left_836   float64
#  6690  EAR_right_836  float64
#  6691  EAR_mean_836   float64
#  6692  MAR_836        float64
#  6693  EBR_836        int64
#  6694  PERCLOS_836    float64
#  6695  HOP_gd_836     float64
#  6696  HOP_hb_836     float64
#  6697  EAR_left_837   float64
#  6698  EAR_right_837  float64
#  6699  EAR_mean_837   float64
#  6700  MAR_837        float64
#  6701  EBR_837        int64
#  6702  PERCLOS_837    float64
#  6703  HOP_gd_837     float64
#  6704  HOP_hb_837     float64
#  6705  EAR_left_838   float64
#  6706  EAR_right_838  float64
#  6707  EAR_mean_838   float64
#  6708  MAR_838        float64
#  6709  EBR_838        int64
#  6710  PERCLOS_838    float64
#  6711  HOP_gd_838     float64
#  6712  HOP_hb_838     float64
#  6713  EAR_left_839   float64
#  6714  EAR_right_839  float64
#  6715  EAR_mean_839   float64
#  6716  MAR_839        float64
#  6717  EBR_839        int64
#  6718  PERCLOS_839    float64
#  6719  HOP_gd_839     float64
#  6720  HOP_hb_839     float64
#  6721  EAR_left_840   float64
#  6722  EAR_right_840  float64
#  6723  EAR_mean_840   float64
#  6724  MAR_840        float64
#  6725  EBR_840        int64
#  6726  PERCLOS_840    float64
#  6727  HOP_gd_840     float64
#  6728  HOP_hb_840     float64
#  6729  EAR_left_841   float64
#  6730  EAR_right_841  float64
#  6731  EAR_mean_841   float64
#  6732  MAR_841        float64
#  6733  EBR_841        int64
#  6734  PERCLOS_841    float64
#  6735  HOP_gd_841     float64
#  6736  HOP_hb_841     float64
#  6737  EAR_left_842   float64
#  6738  EAR_right_842  float64
#  6739  EAR_mean_842   float64
#  6740  MAR_842        float64
#  6741  EBR_842        int64
#  6742  PERCLOS_842    float64
#  6743  HOP_gd_842     float64
#  6744  HOP_hb_842     float64
#  6745  EAR_left_843   float64
#  6746  EAR_right_843  float64
#  6747  EAR_mean_843   float64
#  6748  MAR_843        float64
#  6749  EBR_843        int64
#  6750  PERCLOS_843    float64
#  6751  HOP_gd_843     float64
#  6752  HOP_hb_843     float64
#  6753  EAR_left_844   float64
#  6754  EAR_right_844  float64
#  6755  EAR_mean_844   float64
#  6756  MAR_844        float64
#  6757  EBR_844        int64
#  6758  PERCLOS_844    float64
#  6759  HOP_gd_844     float64
#  6760  HOP_hb_844     float64
#  6761  EAR_left_845   float64
#  6762  EAR_right_845  float64
#  6763  EAR_mean_845   float64
#  6764  MAR_845        float64
#  6765  EBR_845        int64
#  6766  PERCLOS_845    float64
#  6767  HOP_gd_845     float64
#  6768  HOP_hb_845     float64
#  6769  EAR_left_846   float64
#  6770  EAR_right_846  float64
#  6771  EAR_mean_846   float64
#  6772  MAR_846        float64
#  6773  EBR_846        int64
#  6774  PERCLOS_846    float64
#  6775  HOP_gd_846     float64
#  6776  HOP_hb_846     float64
#  6777  EAR_left_847   float64
#  6778  EAR_right_847  float64
#  6779  EAR_mean_847   float64
#  6780  MAR_847        float64
#  6781  EBR_847        int64
#  6782  PERCLOS_847    float64
#  6783  HOP_gd_847     float64
#  6784  HOP_hb_847     float64
#  6785  EAR_left_848   float64
#  6786  EAR_right_848  float64
#  6787  EAR_mean_848   float64
#  6788  MAR_848        float64
#  6789  EBR_848        int64
#  6790  PERCLOS_848    float64
#  6791  HOP_gd_848     float64
#  6792  HOP_hb_848     float64
#  6793  EAR_left_849   float64
#  6794  EAR_right_849  float64
#  6795  EAR_mean_849   float64
#  6796  MAR_849        float64
#  6797  EBR_849        int64
#  6798  PERCLOS_849    float64
#  6799  HOP_gd_849     float64
#  6800  HOP_hb_849     float64
#  6801  EAR_left_850   float64
#  6802  EAR_right_850  float64
#  6803  EAR_mean_850   float64
#  6804  MAR_850        float64
#  6805  EBR_850        int64
#  6806  PERCLOS_850    float64
#  6807  HOP_gd_850     float64
#  6808  HOP_hb_850     float64
#  6809  EAR_left_851   float64
#  6810  EAR_right_851  float64
#  6811  EAR_mean_851   float64
#  6812  MAR_851        float64
#  6813  EBR_851        int64
#  6814  PERCLOS_851    float64
#  6815  HOP_gd_851     float64
#  6816  HOP_hb_851     float64
#  6817  EAR_left_852   float64
#  6818  EAR_right_852  float64
#  6819  EAR_mean_852   float64
#  6820  MAR_852        float64
#  6821  EBR_852        int64
#  6822  PERCLOS_852    float64
#  6823  HOP_gd_852     float64
#  6824  HOP_hb_852     float64
#  6825  EAR_left_853   float64
#  6826  EAR_right_853  float64
#  6827  EAR_mean_853   float64
#  6828  MAR_853        float64
#  6829  EBR_853        int64
#  6830  PERCLOS_853    float64
#  6831  HOP_gd_853     float64
#  6832  HOP_hb_853     float64
#  6833  EAR_left_854   float64
#  6834  EAR_right_854  float64
#  6835  EAR_mean_854   float64
#  6836  MAR_854        float64
#  6837  EBR_854        int64
#  6838  PERCLOS_854    float64
#  6839  HOP_gd_854     float64
#  6840  HOP_hb_854     float64
#  6841  EAR_left_855   float64
#  6842  EAR_right_855  float64
#  6843  EAR_mean_855   float64
#  6844  MAR_855        float64
#  6845  EBR_855        int64
#  6846  PERCLOS_855    float64
#  6847  HOP_gd_855     float64
#  6848  HOP_hb_855     float64
#  6849  EAR_left_856   float64
#  6850  EAR_right_856  float64
#  6851  EAR_mean_856   float64
#  6852  MAR_856        float64
#  6853  EBR_856        int64
#  6854  PERCLOS_856    float64
#  6855  HOP_gd_856     float64
#  6856  HOP_hb_856     float64
#  6857  EAR_left_857   float64
#  6858  EAR_right_857  float64
#  6859  EAR_mean_857   float64
#  6860  MAR_857        float64
#  6861  EBR_857        int64
#  6862  PERCLOS_857    float64
#  6863  HOP_gd_857     float64
#  6864  HOP_hb_857     float64
#  6865  EAR_left_858   float64
#  6866  EAR_right_858  float64
#  6867  EAR_mean_858   float64
#  6868  MAR_858        float64
#  6869  EBR_858        int64
#  6870  PERCLOS_858    float64
#  6871  HOP_gd_858     float64
#  6872  HOP_hb_858     float64
#  6873  EAR_left_859   float64
#  6874  EAR_right_859  float64
#  6875  EAR_mean_859   float64
#  6876  MAR_859        float64
#  6877  EBR_859        int64
#  6878  PERCLOS_859    float64
#  6879  HOP_gd_859     float64
#  6880  HOP_hb_859     float64
#  6881  EAR_left_860   float64
#  6882  EAR_right_860  float64
#  6883  EAR_mean_860   float64
#  6884  MAR_860        float64
#  6885  EBR_860        int64
#  6886  PERCLOS_860    float64
#  6887  HOP_gd_860     float64
#  6888  HOP_hb_860     float64
#  6889  EAR_left_861   float64
#  6890  EAR_right_861  float64
#  6891  EAR_mean_861   float64
#  6892  MAR_861        float64
#  6893  EBR_861        int64
#  6894  PERCLOS_861    float64
#  6895  HOP_gd_861     float64
#  6896  HOP_hb_861     float64
#  6897  EAR_left_862   float64
#  6898  EAR_right_862  float64
#  6899  EAR_mean_862   float64
#  6900  MAR_862        float64
#  6901  EBR_862        int64
#  6902  PERCLOS_862    float64
#  6903  HOP_gd_862     float64
#  6904  HOP_hb_862     float64
#  6905  EAR_left_863   float64
#  6906  EAR_right_863  float64
#  6907  EAR_mean_863   float64
#  6908  MAR_863        float64
#  6909  EBR_863        int64
#  6910  PERCLOS_863    float64
#  6911  HOP_gd_863     float64
#  6912  HOP_hb_863     float64
#  6913  EAR_left_864   float64
#  6914  EAR_right_864  float64
#  6915  EAR_mean_864   float64
#  6916  MAR_864        float64
#  6917  EBR_864        int64
#  6918  PERCLOS_864    float64
#  6919  HOP_gd_864     float64
#  6920  HOP_hb_864     float64
#  6921  EAR_left_865   float64
#  6922  EAR_right_865  float64
#  6923  EAR_mean_865   float64
#  6924  MAR_865        float64
#  6925  EBR_865        int64
#  6926  PERCLOS_865    float64
#  6927  HOP_gd_865     float64
#  6928  HOP_hb_865     float64
#  6929  EAR_left_866   float64
#  6930  EAR_right_866  float64
#  6931  EAR_mean_866   float64
#  6932  MAR_866        float64
#  6933  EBR_866        int64
#  6934  PERCLOS_866    float64
#  6935  HOP_gd_866     float64
#  6936  HOP_hb_866     float64
#  6937  EAR_left_867   float64
#  6938  EAR_right_867  float64
#  6939  EAR_mean_867   float64
#  6940  MAR_867        float64
#  6941  EBR_867        int64
#  6942  PERCLOS_867    float64
#  6943  HOP_gd_867     float64
#  6944  HOP_hb_867     float64
#  6945  EAR_left_868   float64
#  6946  EAR_right_868  float64
#  6947  EAR_mean_868   float64
#  6948  MAR_868        float64
#  6949  EBR_868        int64
#  6950  PERCLOS_868    float64
#  6951  HOP_gd_868     float64
#  6952  HOP_hb_868     float64
#  6953  EAR_left_869   float64
#  6954  EAR_right_869  float64
#  6955  EAR_mean_869   float64
#  6956  MAR_869        float64
#  6957  EBR_869        int64
#  6958  PERCLOS_869    float64
#  6959  HOP_gd_869     float64
#  6960  HOP_hb_869     float64
#  6961  EAR_left_870   float64
#  6962  EAR_right_870  float64
#  6963  EAR_mean_870   float64
#  6964  MAR_870        float64
#  6965  EBR_870        int64
#  6966  PERCLOS_870    float64
#  6967  HOP_gd_870     float64
#  6968  HOP_hb_870     float64
#  6969  EAR_left_871   float64
#  6970  EAR_right_871  float64
#  6971  EAR_mean_871   float64
#  6972  MAR_871        float64
#  6973  EBR_871        int64
#  6974  PERCLOS_871    float64
#  6975  HOP_gd_871     float64
#  6976  HOP_hb_871     float64
#  6977  EAR_left_872   float64
#  6978  EAR_right_872  float64
#  6979  EAR_mean_872   float64
#  6980  MAR_872        float64
#  6981  EBR_872        int64
#  6982  PERCLOS_872    float64
#  6983  HOP_gd_872     float64
#  6984  HOP_hb_872     float64
#  6985  EAR_left_873   float64
#  6986  EAR_right_873  float64
#  6987  EAR_mean_873   float64
#  6988  MAR_873        float64
#  6989  EBR_873        int64
#  6990  PERCLOS_873    float64
#  6991  HOP_gd_873     float64
#  6992  HOP_hb_873     float64
#  6993  EAR_left_874   float64
#  6994  EAR_right_874  float64
#  6995  EAR_mean_874   float64
#  6996  MAR_874        float64
#  6997  EBR_874        int64
#  6998  PERCLOS_874    float64
#  6999  HOP_gd_874     float64
#  7000  HOP_hb_874     float64
#  7001  class          int64
# dtypes: float64(6125), int64(876), object(1)
# memory usage: 65.8+ MB

# %%
data.describe()
# Out:
#         EAR_left_0  EAR_right_0   EAR_mean_0        MAR_0        EBR_0  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      0.283236     0.283655     0.283445     0.017392     0.107143
# std       0.072436     0.078161     0.073578     0.049015     0.309420
# min       0.004692     0.009174     0.011543     0.001132     0.000000
# 25%       0.256963     0.252301     0.254359     0.004749     0.000000
# 50%       0.298256     0.290941     0.296578     0.007724     0.000000
# 75%       0.329450     0.331770     0.330706     0.012957     0.000000
# max       0.431153     0.567635     0.458340     0.924474     1.000000
#
#          PERCLOS_0     HOP_gd_0     HOP_hb_0   EAR_left_1  EAR_right_1  ...  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000  ...
# mean     10.714286    90.009959     2.979275     0.284099     0.284287  ...
# std      30.942039     0.021412     2.944400     0.071916     0.077937  ...
# min       0.000000    89.952202     0.000401     0.003804     0.008502  ...
# 25%       0.000000    89.994887     0.927629     0.258843     0.251512  ...
# 50%       0.000000    90.005859     2.180789     0.299206     0.292115  ...
# 75%       0.000000    90.023899     4.027924     0.330010     0.330818  ...
# max     100.000000    90.085500    20.946429     0.434053     0.568072  ...
#
#         HOP_hb_873  EAR_left_874  EAR_right_874  EAR_mean_874      MAR_874  \
# count  1232.000000   1232.000000    1232.000000   1232.000000  1232.000000
# mean      9.327910      0.272731       0.272462      0.272597     0.015946
# std      32.984484      0.086501       0.092306      0.087916     0.047651
# min       0.001628      0.000000       0.000000      0.000000     0.000000
# 25%       0.975446      0.250476       0.244958      0.248532     0.004361
# 50%       2.282457      0.294678       0.288316      0.293099     0.007258
# 75%       4.444520      0.327370       0.329150      0.328033     0.012150
# max     180.000000      0.462268       0.584731      0.472400     0.839445
#
#            EBR_874  PERCLOS_874   HOP_gd_874   HOP_hb_874        class
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      0.434253     8.283859    93.589759    10.046908     0.969968
# std       0.668834     6.747160    17.593309    34.721867     0.841592
# min       0.000000     0.000000    89.952075     0.000924     0.000000
# 25%       0.000000     3.428571    89.995739     0.967604     0.000000
# 50%       0.000000     6.400000    90.007530     2.290802     1.000000
# 75%       1.000000    11.428571    90.026899     4.501100     2.000000
# max       5.000000    37.142857   180.000000   180.000000     2.000000
#
# [8 rows x 7001 columns]

# %%
data["class"].value_counts()
# Out:
# class
# 0    455
# 2    418
# 1    359
# Name: count, dtype: int64

# %% [markdown]
# We can see there is a slight class imbalance, so we should use a metric other than accuracy to measure our model's performance, or apply data augmentation through oversampling and by adding noise to the data.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Analysis of each sign for each class

# %% [markdown]
# To better understand this data, I will visualize the trend of each sign for each video category.

# %%
def extract_signs(class_means,label, n=875):
    """Extract a list for each sign of the instance

    Args:
        instance (list): instance of data
        n (int, optional): number of instance for a sign. Defaults to 875.

    Returns:
        dict: A list associated to each sign
    """
    row = class_means.loc[label]
    return {
        sign: [row[f"{sign}_{i}"] for i in range(n)]
        for sign in [
            "EAR_left",
            "EAR_right",
            "EAR_mean",
            "MAR",
            "EBR",
            "PERCLOS",
            "HOP_gd",
            "HOP_hb"
        ]
    }

# %%
class_means = data.groupby("class").mean(numeric_only=True)

# Mean of all instances signs
mean_signs_0 = extract_signs(class_means,0)
mean_signs_1 = extract_signs(class_means,1)
mean_signs_2 = extract_signs(class_means,2)

# %%
import matplotlib.pyplot as plt

def plot_signs(signs_0, signs_1, signs_2):

    for sign in signs_0:
        plt.figure(figsize=(12, 5))

        plt.plot(signs_0[sign], label="Class 0")
        plt.plot(signs_1[sign], label="Class 1")
        plt.plot(signs_2[sign], label="Class 2")

        plt.title(sign)
        plt.xlabel("Frame")
        plt.ylabel(sign)
        plt.legend()
        plt.grid()
        plt.savefig(f"graphics/signs_by_class_{sign}.png", dpi=150, bbox_inches="tight")
        plt.show()

# %%
plot_signs(mean_signs_0, mean_signs_1, mean_signs_2)

# %% [markdown]
# ### Distributions
#
# Let's look at the distribution of each sign. To make these distributions easier to interpret, I will plot density curves instead of histograms.

# %%
import numpy as np

signs = ["EAR_left", "EAR_right", "EAR_mean", "MAR", "EBR", "PERCLOS", "HOP_gd", "HOP_hb"]

# une colonne = moyenne du signe sur les 875 frames, pour chaque instance
instance_means = pd.DataFrame({
    sign: data[[f"{sign}_{i}" for i in range(875)]].mean(axis=1)
    for sign in signs
})

import seaborn as sns

for sign in signs:
    plt.figure(figsize=(10, 5))
    for c in sorted(data["class"].unique()):
        sns.kdeplot(instance_means[data["class"] == c][sign], label=f"Class {c}", linewidth=2)
    plt.title(sign)
    plt.xlabel(sign)
    plt.ylabel("Density")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.savefig(f"graphics/kde_{sign}.png", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# For most signs, we observe a different mean and standard deviation for each class. Some fatigue-related signs are heavy-tailed, especially HOP, EBR, PERCLOS, and MAR. EAR is also right-skewed and heavy-tailed, though less so, and remains interpretable, its distribution is closer to normal.

# %% [markdown]
# Let's transform these signs to obtain a better distribution.

# %%
def logit_transform(x, epsilon=1e-6):
    x_clipped = np.clip(x, epsilon, 1 - epsilon)
    return np.log(x_clipped / (1 - x_clipped))

signs_to_transform = ["EBR", "PERCLOS","HOP_hb", "MAR"] # HOP_gd is worst if we transform it 

instance_means_logit = instance_means.copy()
instance_means_logit[signs_to_transform] = instance_means[signs_to_transform].apply(logit_transform)

# %%
for sign in signs:
    plt.figure(figsize=(10, 5))
    for c in sorted(data["class"].unique()):
        sns.kdeplot(instance_means_logit[data["class"] == c][sign], label=f"Class {c}", linewidth=2)
    plt.title(sign)
    plt.xlabel(sign)
    plt.ylabel("Density")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.savefig(f"graphics/kde_logit_{sign}.png", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# From these plots, we can see that EAR is higher when the subject is more alert and decreases with fatigue, the opposite pattern from MAR, HOP, EBR, and PERCLOS, whose values are slightly higher and much more frequent in fatigued subjects than in awake ones.

# %% [markdown]
# ### Correlations

# %% [markdown]
# Let's look at how the features correlate with each other. Some of them are naturally expected to be correlated (e.g., EAR, HOP).

# %%
corr = instance_means.corr()

import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlations Between Signs")
plt.savefig("graphics/correlation_heatmap.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# The heatmap shows a few expected redundancies. EAR_left, EAR_right, and EAR_mean are highly correlated (0.85–0.97), as they all measure the same phenomenon from the left and right eyes. EBR and PERCLOS are also strongly correlated (0.78), since both are related to eye-closure behavior. HOP_gd and HOP_hb have a moderate correlation (0.51), as both are related to head orientation.
#
# The most interesting relationships are the moderate negative correlations between EAR and EBR/PERCLOS (-0.39 to -0.63). This means that lower average eye openness is associated with more blinking and longer eye-closure periods, which is consistent with a fatigue-related signal. MAR has a weak to moderate positive correlation with EBR and PERCLOS (0.30–0.32), suggesting that yawning can sometimes occur together with blinking or eye closure, although this relationship is weaker than the one observed with EAR.
#
# Finally, the correlations between MAR/EAR and the HOP features are weak (|r| < 0.21), so these relationships should not be over-interpreted based on this analysis alone.
